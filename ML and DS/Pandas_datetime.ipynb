# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('cs_hltv_data.csv')

# %%
df.shape
# Out:
# (3490, 157)

# %%
df.head(15)
# Out:
#     Unnamed: 0        date   time     first_team   second_team  \
# 0            0  2021-06-02  10:00          Fiend           K23
# 1            1  2021-06-02  10:00       Entropiq           BIG
# 2            2  2021-06-02  07:00       Entropiq        Nemiga
# 3            3  2021-06-02  07:00             OG         Fiend
# 4            4  2021-06-01  14:15            BIG  Wisla Krakow
# 5            5  2021-06-01  13:00         fnatic         Fiend
# 6            6  2021-06-01  13:00  Natus Vincere      Entropiq
# 7            7  2021-06-01  10:00            BIG  Wisla Krakow
# 8            8  2021-06-01  09:00       Entropiq           AVE
# 9            9  2021-06-01  07:00             OG          1WIN
# 10          10  2021-06-01  04:00          forZe      Entropiq
# 11          11  2021-05-31  10:00          SKADE         Fiend
# 12          12  2021-05-31  04:00            AGO      Entropiq
# 13          13  2021-05-30  16:55    mousesports           NIP
# ...

# %%
df.date = pd.to_datetime(df.date)

# %%
df.info(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3490 entries, 0 to 3489
# Data columns (total 157 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    Unnamed: 0                int64
#  1    date                      datetime64[ns]
#  2    time                      object
#  3    first_team                object
#  4    second_team               object
#  5    first_team_world_rank_#   object
#  6    second_team_world_rank_#  object
#  7    first_team_total_score    int64
#  8    second_team_total_score   int64
#  9    first_team_won            int64
#  10   M1                        object
#  11   first_team_score_M1       int64
#  12   second_team_score_M1      int64
#  13   M2                        object
#  14   first_team_score_M2       int64
#  15   second_team_score_M2      int64
#  16   M3                        object
#  17   first_team_score_M3       object
#  18   second_team_score_M3      object
# ...

# %%
df['day of the week'] = df.date.dt.day_name() 
#The date column is a datetime object which has a method day_name..
#This method is being called for each row entry and we get the day of the week for each date
#We add this data back into our dataframe in form of a new column named 'day of the week'

# %%
df.head()
# Out:
#    Unnamed: 0       date   time first_team   second_team  \
# 0           0 2021-06-02  10:00      Fiend           K23
# 1           1 2021-06-02  10:00   Entropiq           BIG
# 2           2 2021-06-02  07:00   Entropiq        Nemiga
# 3           3 2021-06-02  07:00         OG         Fiend
# 4           4 2021-06-01  14:15        BIG  Wisla Krakow
#
#   first_team_world_rank_# second_team_world_rank_#  first_team_total_score  \
# 0                      28                       27                       0
# 1                      15                        8                       0
# 2                      15                       52                       2
# 3                      20                       28                       2
# 4                       8                       49                       2
#
#    second_team_total_score  first_team_won  ...    ban 1     ban 2    pick 1  \
# 0                        2               0  ...   Mirage   Vertigo  Overpass
# ...
